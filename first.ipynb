# %% [markdown]
# **Install the Packages**

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Load the Image or read the Image**

# %%
image_cv = cv2.imread("/content/joker.jpeg")
cv2_imshow(image_cv)
# Out:
# <PIL.Image.Image image mode=RGB size=377x570>

# %% [markdown]
# **Every Images is Pixel**

# %%
image_cv.shape
#Blu color intesity 251
#Green color intensity 253
#Red colot intensity 254
# Out:
# (570, 377, 3)

# %%
image_cv
# Out:
# array([[[251, 253, 254],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255],
#         ...,
#         [253, 255, 255],
#         [252, 254, 254],
#         [254, 254, 254]],
#
#        [[248, 252, 253],
#         [249, 253, 254],
#         [251, 255, 255],
#         ...,
#         [253, 255, 254],
#         [252, 255, 253],
#         [255, 255, 254]],
#
#        ...,
#
#        [[ 55,  44,  77],
#         [ 61,  50,  83],
#         [147, 136, 169],
#         ...,
#         [ 15,  22,  15],
#         [ 15,  22,  15],
#         [ 15,  22,  15]],
#
#        [[ 65,  57,  80],
#         [ 62,  54,  77],
#         [ 89,  80, 106],
#         ...,
#         [ 24,  32,  25],
#         [ 22,  30,  23],
#         [ 19,  27,  20]],
#
#        [[131, 125, 144],
#         [113, 107, 126],
#         [ 81,  74,  95],
#         ...,
#         [ 26,  37,  29],
#         [ 24,  35,  27],
#         [ 21,  32,  24]]], dtype=uint8)

# %%
b,g,r =cv2.split(image_cv)

# %%
print(b)
print(g)
print(r)
# Out:
# [[251 253 253 ... 253 253 255]
#  [253 253 253 ... 253 252 254]
#  [248 249 251 ... 253 252 255]
#  ...
#  [ 55  61 147 ...  15  15  15]
#  [ 65  62  89 ...  24  22  19]
#  [131 113  81 ...  26  24  21]]
# [[253 255 255 ... 255 255 255]
#  [255 255 255 ... 255 254 254]
#  [252 253 255 ... 255 255 255]
#  ...
#  [ 44  50 136 ...  22  22  22]
#  [ 57  54  80 ...  32  30  27]
#  [125 107  74 ...  37  35  32]]
# [[254 255 255 ... 255 255 255]
#  [255 255 255 ... 255 254 254]
#  [253 254 255 ... 254 253 254]
#  ...
#  [ 77  83 169 ...  15  15  15]
#  [ 80  77 106 ...  25  23  20]
#  [144 126  95 ...  29  27  24]]

# %%
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=377x570>

# %%
cv2_imshow(g)
# Out:
# <PIL.Image.Image image mode=L size=377x570>

# %%
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=377x570>

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(r,cmap="Reds")

# %%
plt.imshow(g,cmap="Greens")

# %%
plt.imshow(b,cmap="Blues")
